# %%
# !pip install opendatasets --upgrade --quiet

import pandas as pd
import os
import opendatasets as od

# Assign the Kaggle data set URL into variable
dataset = 'https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images'
# Using opendatasets let's download the data sets
# od.download(dataset)
# # {"username":"kganeshv","key":"224eab20b74a0a68fc7194190f513131"}
# Out:
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
dataset_dir = "cifake-real-and-ai-generated-synthetic-images" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: cifake-real-and-ai-generated-synthetic-images

# %%
# Check if GPUs are available for training
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
img_height = 32
img_width = 32
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
Net_base_model = tf.keras.applications.EfficientNetB6(
    include_top = False,
    weights = 'imagenet',
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
Net_base_model.trainable = True


inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = Net_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256,
          kernel_regularizer = regularizers.l2(0.01),
          activity_regularizer = regularizers.l1(0.01),
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
Net_model = tf.keras.Model(inputs, outputs)

# Compile the model
Net_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Summary of the model
Net_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb6_notop.h5
# 165234480/165234480 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  efficientnetb6 (Functional)  (None, 2304)             40960143
#
#  batch_normalization (BatchN  (None, 2304)             9216
#  ormalization)
#
#  dense (Dense)               (None, 256)               590080
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 41,575,952
# Trainable params: 41,346,905
# Non-trainable params: 229,047
# _________________________________________________________________

# %%
# Train the Transfer Learning model
print("Starting training with Transfer Learning using Net50...")
ResNet_model_history = Net_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using Net50...
# Epoch 1/100
# 200/200 [==============================] - 103s 321ms/step - loss: 2.5937 - accuracy: 0.9114 - precision: 0.9158 - recall: 0.9061 - val_loss: 1.9974 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.8327 - accuracy: 0.9640 - precision: 0.9652 - recall: 0.9627 - val_loss: 0.5941 - val_accuracy: 0.9633 - val_precision: 0.9469 - val_recall: 0.9816
# Epoch 3/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.3793 - accuracy: 0.9745 - precision: 0.9747 - recall: 0.9743 - val_loss: 0.3179 - val_accuracy: 0.9628 - val_precision: 0.9855 - val_recall: 0.9394
# Epoch 4/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.1993 - accuracy: 0.9814 - precision: 0.9818 - recall: 0.9811 - val_loss: 1.1368 - val_accuracy: 0.5346 - val_precision: 1.0000 - val_recall: 0.0692
# Epoch 5/100
# 200/200 [==============================] - 58s 288ms/step - loss: 0.1169 - accuracy: 0.9867 - precision: 0.9870 - recall: 0.9863 - val_loss: 0.5378 - val_accuracy: 0.7596 - val_precision: 0.9998 - val_recall: 0.5193
# Epoch 6/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0762 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9905 - val_loss: 0.5149 - val_accuracy: 0.8967 - val_precision: 0.9982 - val_recall: 0.7948
# Epoch 7/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0534 - accuracy: 0.9943 - precision: 0.9942 - recall: 0.9943 - val_loss: 0.6065 - val_accuracy: 0.8498 - val_precision: 0.9990 - val_recall: 0.7003
# Epoch 8/100
# 200/200 [==============================] - 59s 293ms/step - loss: 0.0407 - accuracy: 0.9961 - precision: 0.9961 - recall: 0.9960 - val_loss: 0.2013 - val_accuracy: 0.9556 - val_precision: 0.9933 - val_recall: 0.9175
# Epoch 9/100
# 200/200 [==============================] - 59s 292ms/step - loss: 0.0352 - accuracy: 0.9966 - precision: 0.9967 - recall: 0.9965 - val_loss: 0.1325 - val_accuracy: 0.9706 - val_precision: 0.9862 - val_recall: 0.9545
# Epoch 10/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0286 - accuracy: 0.9979 - precision: 0.9980 - recall: 0.9978 - val_loss: 0.1461 - val_accuracy: 0.9750 - val_precision: 0.9751 - val_recall: 0.9750
# Epoch 11/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0266 - accuracy: 0.9978 - precision: 0.9977 - recall: 0.9979 - val_loss: 0.1433 - val_accuracy: 0.9727 - val_precision: 0.9836 - val_recall: 0.9614
# Epoch 12/100
# 200/200 [==============================] - 58s 288ms/step - loss: 0.0214 - accuracy: 0.9990 - precision: 0.9989 - recall: 0.9990 - val_loss: 0.1477 - val_accuracy: 0.9702 - val_precision: 0.9850 - val_recall: 0.9549
# Epoch 13/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0229 - accuracy: 0.9977 - precision: 0.9979 - recall: 0.9976 - val_loss: 0.6555 - val_accuracy: 0.8893 - val_precision: 0.9982 - val_recall: 0.7801
# Epoch 14/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0186 - accuracy: 0.9989 - precision: 0.9989 - recall: 0.9988 - val_loss: 0.1618 - val_accuracy: 0.9749 - val_precision: 0.9753 - val_recall: 0.9745
# Epoch 15/100
# 200/200 [==============================] - 62s 312ms/step - loss: 0.0170 - accuracy: 0.9990 - precision: 0.9991 - recall: 0.9989 - val_loss: 0.1547 - val_accuracy: 0.9709 - val_precision: 0.9853 - val_recall: 0.9561
# Epoch 16/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0165 - accuracy: 0.9989 - precision: 0.9990 - recall: 0.9989 - val_loss: 0.1102 - val_accuracy: 0.9718 - val_precision: 0.9608 - val_recall: 0.9836
# Epoch 17/100
# 200/200 [==============================] - 58s 287ms/step - loss: 0.0148 - accuracy: 0.9991 - precision: 0.9991 - recall: 0.9992 - val_loss: 0.1611 - val_accuracy: 0.9696 - val_precision: 0.9861 - val_recall: 0.9527
# Epoch 18/100
# 200/200 [==============================] - 58s 287ms/step - loss: 0.0154 - accuracy: 0.9986 - precision: 0.9988 - recall: 0.9985 - val_loss: 0.2833 - val_accuracy: 0.9563 - val_precision: 0.9940 - val_recall: 0.9180
# Epoch 19/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0114 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9997 - val_loss: 0.1438 - val_accuracy: 0.9755 - val_precision: 0.9771 - val_recall: 0.9738
# Epoch 20/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0120 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.1714 - val_accuracy: 0.9756 - val_precision: 0.9759 - val_recall: 0.9753
# Epoch 21/100
# 200/200 [==============================] - 58s 287ms/step - loss: 0.0102 - accuracy: 0.9998 - precision: 0.9999 - recall: 0.9998 - val_loss: 0.1518 - val_accuracy: 0.9762 - val_precision: 0.9794 - val_recall: 0.9730
# Epoch 22/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0110 - accuracy: 0.9994 - precision: 0.9995 - recall: 0.9993 - val_loss: 0.1031 - val_accuracy: 0.9758 - val_precision: 0.9747 - val_recall: 0.9769
# Epoch 23/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0109 - accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - val_loss: 0.1556 - val_accuracy: 0.9496 - val_precision: 0.9955 - val_recall: 0.9033
# Epoch 24/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0103 - accuracy: 0.9994 - precision: 0.9996 - recall: 0.9993 - val_loss: 0.1618 - val_accuracy: 0.9753 - val_precision: 0.9694 - val_recall: 0.9815
# Epoch 25/100
# 200/200 [==============================] - 58s 288ms/step - loss: 0.0092 - accuracy: 0.9996 - precision: 0.9997 - recall: 0.9996 - val_loss: 0.1640 - val_accuracy: 0.9707 - val_precision: 0.9868 - val_recall: 0.9543
# Epoch 26/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0101 - accuracy: 0.9993 - precision: 0.9993 - recall: 0.9992 - val_loss: 0.1002 - val_accuracy: 0.9748 - val_precision: 0.9823 - val_recall: 0.9670
# Epoch 27/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0089 - accuracy: 0.9995 - precision: 0.9995 - recall: 0.9994 - val_loss: 0.2781 - val_accuracy: 0.9666 - val_precision: 0.9440 - val_recall: 0.9921
# Epoch 28/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0086 - accuracy: 0.9995 - precision: 0.9997 - recall: 0.9994 - val_loss: 0.4982 - val_accuracy: 0.9534 - val_precision: 0.9183 - val_recall: 0.9953
# Epoch 29/100
# 200/200 [==============================] - 59s 292ms/step - loss: 0.0096 - accuracy: 0.9992 - precision: 0.9993 - recall: 0.9992 - val_loss: 0.2212 - val_accuracy: 0.9713 - val_precision: 0.9871 - val_recall: 0.9551
# Epoch 30/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0078 - accuracy: 0.9996 - precision: 0.9997 - recall: 0.9996 - val_loss: 0.1181 - val_accuracy: 0.9677 - val_precision: 0.9906 - val_recall: 0.9444
# Epoch 31/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0088 - accuracy: 0.9994 - precision: 0.9994 - recall: 0.9993 - val_loss: 0.0995 - val_accuracy: 0.9750 - val_precision: 0.9727 - val_recall: 0.9774
# Epoch 32/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0077 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9994 - val_loss: 0.3667 - val_accuracy: 0.8996 - val_precision: 0.9988 - val_recall: 0.8003
# Epoch 33/100
# 200/200 [==============================] - 58s 287ms/step - loss: 0.0067 - accuracy: 0.9998 - precision: 0.9999 - recall: 0.9998 - val_loss: 0.2449 - val_accuracy: 0.9713 - val_precision: 0.9555 - val_recall: 0.9887
# Epoch 34/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0060 - accuracy: 0.9999 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.1721 - val_accuracy: 0.9765 - val_precision: 0.9809 - val_recall: 0.9718
# Epoch 35/100
# 200/200 [==============================] - 58s 288ms/step - loss: 0.0057 - accuracy: 0.9999 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.1611 - val_accuracy: 0.9773 - val_precision: 0.9783 - val_recall: 0.9764
# Epoch 36/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0055 - accuracy: 0.9999 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.1694 - val_accuracy: 0.9778 - val_precision: 0.9758 - val_recall: 0.9798
# Epoch 37/100
# 200/200 [==============================] - 58s 288ms/step - loss: 0.0053 - accuracy: 1.0000 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.1816 - val_accuracy: 0.9757 - val_precision: 0.9827 - val_recall: 0.9683
# Epoch 38/100
# 200/200 [==============================] - 63s 314ms/step - loss: 0.0079 - accuracy: 0.9993 - precision: 0.9995 - recall: 0.9992 - val_loss: 0.2760 - val_accuracy: 0.9747 - val_precision: 0.9678 - val_recall: 0.9820
# Epoch 39/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0061 - accuracy: 0.9998 - precision: 0.9998 - recall: 0.9997 - val_loss: 0.1777 - val_accuracy: 0.9762 - val_precision: 0.9792 - val_recall: 0.9731
# Epoch 40/100
# 200/200 [==============================] - 59s 291ms/step - loss: 0.0063 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9994 - val_loss: 0.0894 - val_accuracy: 0.9629 - val_precision: 0.9889 - val_recall: 0.9364
# Epoch 41/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0076 - accuracy: 0.9993 - precision: 0.9994 - recall: 0.9992 - val_loss: 0.2619 - val_accuracy: 0.9743 - val_precision: 0.9658 - val_recall: 0.9833
# Epoch 42/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0063 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9994 - val_loss: 0.1438 - val_accuracy: 0.9764 - val_precision: 0.9742 - val_recall: 0.9786
# Epoch 43/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0059 - accuracy: 0.9997 - precision: 0.9997 - recall: 0.9997 - val_loss: 0.1831 - val_accuracy: 0.9737 - val_precision: 0.9819 - val_recall: 0.9653
# Epoch 44/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0067 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9994 - val_loss: 0.1352 - val_accuracy: 0.9767 - val_precision: 0.9723 - val_recall: 0.9814
# Epoch 45/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0062 - accuracy: 0.9996 - precision: 0.9996 - recall: 0.9995 - val_loss: 0.2207 - val_accuracy: 0.9664 - val_precision: 0.9911 - val_recall: 0.9414
# Epoch 46/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0061 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9995 - val_loss: 0.1019 - val_accuracy: 0.9635 - val_precision: 0.9414 - val_recall: 0.9886
# Epoch 47/100
# 200/200 [==============================] - 58s 289ms/step - loss: 0.0066 - accuracy: 0.9995 - precision: 0.9997 - recall: 0.9994 - val_loss: 0.2329 - val_accuracy: 0.9721 - val_precision: 0.9547 - val_recall: 0.9912
# Epoch 48/100
# 200/200 [==============================] - 58s 288ms/step - loss: 0.0058 - accuracy: 0.9997 - precision: 0.9997 - recall: 0.9996 - val_loss: 0.3724 - val_accuracy: 0.9606 - val_precision: 0.9925 - val_recall: 0.9282
# Epoch 49/100
# 200/200 [==============================] - 58s 291ms/step - loss: 0.0061 - accuracy: 0.9995 - precision: 0.9996 - recall: 0.9995 - val_loss: 2.7776 - val_accuracy: 0.5006 - val_precision: 0.5003 - val_recall: 1.0000
# Epoch 50/100
# 200/200 [==============================] - 58s 290ms/step - loss: 0.0061 - accuracy: 0.9995 - precision: 0.9997 - recall: 0.9993 - val_loss: 0.3688 - val_accuracy: 0.9681 - val_precision: 0.9896 - val_recall: 0.9461
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = Net_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 [==============================] - 6s 134ms/step - loss: 0.0894 - accuracy: 0.9629 - precision: 0.9889 - recall: 0.9364
# Val Loss: 0.0894
# Val Accuracy: 0.9629
# Val Precision: 0.9889
# Val Recall: 0.9364

# %%
# Plot error rates and metric rates
plot_metrics(ResNet_model_history, 'loss')
plot_metrics(ResNet_model_history, 'accuracy')
plot_metrics(ResNet_model_history, 'precision')
plot_metrics(ResNet_model_history, 'recall')
