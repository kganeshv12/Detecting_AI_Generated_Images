# %%
# !pip install opendatasets --upgrade --quiet

import pandas as pd
import os
import opendatasets as od

# Assign the Kaggle data set URL into variable
dataset = 'https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images'
# Using opendatasets let's download the data sets
od.download(dataset)
# # {"username":"kganeshv","key":"224eab20b74a0a68fc7194190f513131"}
# Out:
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: kganeshv
# Your Kaggle Key: ········
# Dataset URL: https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images
# Downloading cifake-real-and-ai-generated-synthetic-images.zip to ./cifake-real-and-ai-generated-synthetic-images
# 100%|████████████████████████████████████████████████████████████████████████████████| 105M/105M [00:01<00:00, 95.8MB/s]

# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
dataset_dir = "cifake-real-and-ai-generated-synthetic-images" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: cifake-real-and-ai-generated-synthetic-images

# %%
# Check if GPUs are available for training
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
img_height = 32
img_width = 32
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
Net_base_model = tf.keras.applications.EfficientNetB4(
    include_top = False,
    weights = 'imagenet',
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
Net_base_model.trainable = True


inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = Net_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256,
          kernel_regularizer = regularizers.l2(0.01),
          activity_regularizer = regularizers.l1(0.01),
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
Net_model = tf.keras.Model(inputs, outputs)

# Compile the model
Net_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Summary of the model
Net_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  efficientnetb4 (Functional)  (None, 1792)             17673823
#
#  batch_normalization (BatchN  (None, 1792)             7168
#  ormalization)
#
#  dense (Dense)               (None, 256)               459008
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 18,156,512
# Trainable params: 18,027,721
# Non-trainable params: 128,791
# _________________________________________________________________

# %%
# Train the Transfer Learning model
print("Starting training with Transfer Learning using Net50...")
ResNet_model_history = Net_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using Net50...
# Epoch 1/100
# 200/200 [==============================] - 71s 210ms/step - loss: 1.2768 - accuracy: 0.9346 - precision: 0.9360 - recall: 0.9330 - val_loss: 0.5733 - val_accuracy: 0.9149 - val_precision: 0.8590 - val_recall: 0.9928
# Epoch 2/100
# 200/200 [==============================] - 37s 183ms/step - loss: 0.1975 - accuracy: 0.9709 - precision: 0.9717 - recall: 0.9700 - val_loss: 0.1769 - val_accuracy: 0.9660 - val_precision: 0.9791 - val_recall: 0.9522
# Epoch 3/100
# 200/200 [==============================] - 36s 180ms/step - loss: 0.1143 - accuracy: 0.9790 - precision: 0.9798 - recall: 0.9780 - val_loss: 0.7864 - val_accuracy: 0.7140 - val_precision: 0.6362 - val_recall: 1.0000
# Epoch 4/100
# 200/200 [==============================] - 37s 182ms/step - loss: 0.0827 - accuracy: 0.9853 - precision: 0.9857 - recall: 0.9849 - val_loss: 0.2096 - val_accuracy: 0.9320 - val_precision: 0.9964 - val_recall: 0.8671
# Epoch 5/100
# 200/200 [==============================] - 36s 181ms/step - loss: 0.0653 - accuracy: 0.9891 - precision: 0.9898 - recall: 0.9885 - val_loss: 0.5948 - val_accuracy: 0.7033 - val_precision: 1.0000 - val_recall: 0.4066
# Epoch 6/100
# 200/200 [==============================] - 37s 182ms/step - loss: 0.0508 - accuracy: 0.9927 - precision: 0.9929 - recall: 0.9924 - val_loss: 0.4288 - val_accuracy: 0.9746 - val_precision: 0.9781 - val_recall: 0.9708
# Epoch 7/100
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0420 - accuracy: 0.9943 - precision: 0.9945 - recall: 0.9940 - val_loss: 0.4616 - val_accuracy: 0.8432 - val_precision: 0.9999 - val_recall: 0.6866
# Epoch 8/100
# 200/200 [==============================] - 36s 181ms/step - loss: 0.0324 - accuracy: 0.9965 - precision: 0.9964 - recall: 0.9965 - val_loss: 0.1739 - val_accuracy: 0.9653 - val_precision: 0.9412 - val_recall: 0.9925
# Epoch 9/100
# 200/200 [==============================] - 37s 182ms/step - loss: 0.0295 - accuracy: 0.9966 - precision: 0.9968 - recall: 0.9965 - val_loss: 0.0847 - val_accuracy: 0.9735 - val_precision: 0.9608 - val_recall: 0.9872
# Epoch 10/100
# 200/200 [==============================] - 38s 190ms/step - loss: 0.0252 - accuracy: 0.9977 - precision: 0.9978 - recall: 0.9977 - val_loss: 0.1781 - val_accuracy: 0.9735 - val_precision: 0.9639 - val_recall: 0.9839
# Epoch 11/100
# 200/200 [==============================] - 37s 181ms/step - loss: 0.0217 - accuracy: 0.9980 - precision: 0.9981 - recall: 0.9979 - val_loss: 0.1799 - val_accuracy: 0.9728 - val_precision: 0.9866 - val_recall: 0.9585
# Epoch 12/100
# 200/200 [==============================] - 36s 181ms/step - loss: 0.0200 - accuracy: 0.9983 - precision: 0.9984 - recall: 0.9981 - val_loss: 0.9550 - val_accuracy: 0.8307 - val_precision: 0.9997 - val_recall: 0.6617
# Epoch 13/100
# 200/200 [==============================] - 37s 181ms/step - loss: 0.0181 - accuracy: 0.9985 - precision: 0.9987 - recall: 0.9983 - val_loss: 7.6083 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 14/100
# 200/200 [==============================] - 37s 181ms/step - loss: 0.0162 - accuracy: 0.9989 - precision: 0.9990 - recall: 0.9989 - val_loss: 0.6170 - val_accuracy: 0.5006 - val_precision: 1.0000 - val_recall: 0.0013
# Epoch 15/100
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0142 - accuracy: 0.9991 - precision: 0.9992 - recall: 0.9989 - val_loss: 8.5614 - val_accuracy: 0.5002 - val_precision: 0.5001 - val_recall: 1.0000
# Epoch 16/100
# 200/200 [==============================] - 36s 181ms/step - loss: 0.0149 - accuracy: 0.9987 - precision: 0.9987 - recall: 0.9988 - val_loss: 0.4841 - val_accuracy: 0.9392 - val_precision: 0.8934 - val_recall: 0.9975
# Epoch 17/100
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0133 - accuracy: 0.9991 - precision: 0.9989 - recall: 0.9993 - val_loss: 3.4135 - val_accuracy: 0.5832 - val_precision: 0.5454 - val_recall: 1.0000
# Epoch 18/100
# 200/200 [==============================] - 37s 181ms/step - loss: 0.0124 - accuracy: 0.9992 - precision: 0.9993 - recall: 0.9992 - val_loss: 0.1511 - val_accuracy: 0.9756 - val_precision: 0.9849 - val_recall: 0.9660
# Epoch 19/100
# 200/200 [==============================] - 37s 182ms/step - loss: 0.0124 - accuracy: 0.9990 - precision: 0.9989 - recall: 0.9991 - val_loss: 7.3756 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = Net_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 [==============================] - 4s 86ms/step - loss: 0.0847 - accuracy: 0.9735 - precision: 0.9608 - recall: 0.9872
# Val Loss: 0.0847
# Val Accuracy: 0.9735
# Val Precision: 0.9608
# Val Recall: 0.9872

# %%
# Plot error rates and metric rates
plot_metrics(ResNet_model_history, 'loss')
plot_metrics(ResNet_model_history, 'accuracy')
plot_metrics(ResNet_model_history, 'precision')
plot_metrics(ResNet_model_history, 'recall')
