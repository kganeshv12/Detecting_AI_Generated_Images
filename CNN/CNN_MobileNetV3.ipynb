# %%
# !pip install opendatasets --upgrade --quiet

import pandas as pd
import os
import opendatasets as od

# Assign the Kaggle data set URL into variable
dataset = 'https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images'
# Using opendatasets let's download the data sets
# od.download(dataset)
# # {"username":"kganeshv","key":"224eab20b74a0a68fc7194190f513131"}
# Out:
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
dataset_dir = "cifake-real-and-ai-generated-synthetic-images" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: cifake-real-and-ai-generated-synthetic-images

# %%
# Check if GPUs are available for training
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
img_height = 32
img_width = 32
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
Net_base_model = tf.keras.applications.MobileNetV3Large(
    include_top = False,
    weights = 'imagenet',
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
Net_base_model.trainable = True


inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = Net_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256,
          kernel_regularizer = regularizers.l2(0.01),
          activity_regularizer = regularizers.l1(0.01),
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
Net_model = tf.keras.Model(inputs, outputs)

# Compile the model
Net_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Summary of the model
Net_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  MobilenetV3large (Functiona  (None, 960)              2996352
#  l)
#
#  batch_normalization (BatchN  (None, 960)              3840
#  ormalization)
#
#  dense (Dense)               (None, 256)               246016
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 3,262,721
# Trainable params: 3,236,401
# Non-trainable params: 26,320
# _________________________________________________________________

# %%
# Train the Transfer Learning model
print("Starting training with Transfer Learning using Net50...")
ResNet_model_history = Net_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using Net50...
# Epoch 1/100
# 200/200 [==============================] - 25s 72ms/step - loss: 1.2924 - accuracy: 0.8857 - precision: 0.8871 - recall: 0.8839 - val_loss: 0.4411 - val_accuracy: 0.9067 - val_precision: 0.9826 - val_recall: 0.8281
# Epoch 2/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.2511 - accuracy: 0.9470 - precision: 0.9488 - recall: 0.9451 - val_loss: 0.3400 - val_accuracy: 0.8748 - val_precision: 0.8021 - val_recall: 0.9952
# Epoch 3/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.1644 - accuracy: 0.9571 - precision: 0.9587 - recall: 0.9554 - val_loss: 0.1470 - val_accuracy: 0.9581 - val_precision: 0.9657 - val_recall: 0.9499
# Epoch 4/100
# 200/200 [==============================] - 14s 70ms/step - loss: 0.1334 - accuracy: 0.9635 - precision: 0.9640 - recall: 0.9630 - val_loss: 0.2793 - val_accuracy: 0.8959 - val_precision: 0.8304 - val_recall: 0.9951
# Epoch 5/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.1149 - accuracy: 0.9687 - precision: 0.9692 - recall: 0.9681 - val_loss: 0.1497 - val_accuracy: 0.9509 - val_precision: 0.9216 - val_recall: 0.9855
# Epoch 6/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.0990 - accuracy: 0.9736 - precision: 0.9734 - recall: 0.9737 - val_loss: 0.1382 - val_accuracy: 0.9565 - val_precision: 0.9817 - val_recall: 0.9303
# Epoch 7/100
# 200/200 [==============================] - 14s 70ms/step - loss: 0.0859 - accuracy: 0.9772 - precision: 0.9769 - recall: 0.9774 - val_loss: 0.1241 - val_accuracy: 0.9601 - val_precision: 0.9457 - val_recall: 0.9763
# Epoch 8/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.0742 - accuracy: 0.9810 - precision: 0.9807 - recall: 0.9812 - val_loss: 0.1148 - val_accuracy: 0.9647 - val_precision: 0.9749 - val_recall: 0.9540
# Epoch 9/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.0663 - accuracy: 0.9827 - precision: 0.9828 - recall: 0.9826 - val_loss: 0.1230 - val_accuracy: 0.9651 - val_precision: 0.9622 - val_recall: 0.9683
# Epoch 10/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.0569 - accuracy: 0.9854 - precision: 0.9851 - recall: 0.9858 - val_loss: 0.1156 - val_accuracy: 0.9644 - val_precision: 0.9698 - val_recall: 0.9587
# Epoch 11/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.0517 - accuracy: 0.9872 - precision: 0.9868 - recall: 0.9876 - val_loss: 0.1472 - val_accuracy: 0.9580 - val_precision: 0.9364 - val_recall: 0.9827
# Epoch 12/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.0445 - accuracy: 0.9894 - precision: 0.9889 - recall: 0.9900 - val_loss: 0.1320 - val_accuracy: 0.9610 - val_precision: 0.9798 - val_recall: 0.9414
# Epoch 13/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.0407 - accuracy: 0.9904 - precision: 0.9904 - recall: 0.9905 - val_loss: 0.1531 - val_accuracy: 0.9591 - val_precision: 0.9826 - val_recall: 0.9348
# Epoch 14/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.0348 - accuracy: 0.9922 - precision: 0.9920 - recall: 0.9923 - val_loss: 0.1305 - val_accuracy: 0.9643 - val_precision: 0.9609 - val_recall: 0.9679
# Epoch 15/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.0312 - accuracy: 0.9931 - precision: 0.9926 - recall: 0.9936 - val_loss: 0.1409 - val_accuracy: 0.9617 - val_precision: 0.9824 - val_recall: 0.9401
# Epoch 16/100
# 200/200 [==============================] - 13s 64ms/step - loss: 0.0286 - accuracy: 0.9938 - precision: 0.9933 - recall: 0.9942 - val_loss: 0.2094 - val_accuracy: 0.9426 - val_precision: 0.9058 - val_recall: 0.9880
# Epoch 17/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.0267 - accuracy: 0.9944 - precision: 0.9943 - recall: 0.9946 - val_loss: 0.1649 - val_accuracy: 0.9582 - val_precision: 0.9845 - val_recall: 0.9312
# Epoch 18/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.0235 - accuracy: 0.9951 - precision: 0.9948 - recall: 0.9953 - val_loss: 0.1471 - val_accuracy: 0.9673 - val_precision: 0.9658 - val_recall: 0.9689
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = Net_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 [==============================] - 2s 33ms/step - loss: 0.1148 - accuracy: 0.9647 - precision: 0.9749 - recall: 0.9540
# Val Loss: 0.1148
# Val Accuracy: 0.9647
# Val Precision: 0.9749
# Val Recall: 0.9540

# %%
# Plot error rates and metric rates
plot_metrics(ResNet_model_history, 'loss')
plot_metrics(ResNet_model_history, 'accuracy')
plot_metrics(ResNet_model_history, 'precision')
plot_metrics(ResNet_model_history, 'recall')
