# %%
# !pip install opendatasets --upgrade --quiet

import pandas as pd
import os
import opendatasets as od

# Assign the Kaggle data set URL into variable
dataset = 'https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images'
# Using opendatasets let's download the data sets
# od.download(dataset)
# # {"username":"kganeshv","key":"224eab20b74a0a68fc7194190f513131"}
# Out:
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
dataset_dir = "cifake-real-and-ai-generated-synthetic-images" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: cifake-real-and-ai-generated-synthetic-images

# %%
# Check if GPUs are available for training
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
img_height = 32
img_width = 32
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
Net_base_model = tf.keras.applications.MobileNetV2(
    include_top = False,
    weights = 'imagenet',
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
Net_base_model.trainable = True


inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = Net_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256,
          kernel_regularizer = regularizers.l2(0.01),
          activity_regularizer = regularizers.l1(0.01),
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
Net_model = tf.keras.Model(inputs, outputs)

# Compile the model
Net_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Summary of the model
Net_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  mobilenetv2_1.00_224 (Funct  (None, 1280)             2257984
#  ional)
#
#  batch_normalization (BatchN  (None, 1280)             5120
#  ormalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,607,553
# Trainable params: 2,570,881
# Non-trainable params: 36,672
# _________________________________________________________________

# %%
# Train the Transfer Learning model
print("Starting training with Transfer Learning using Net50...")
ResNet_model_history = Net_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using Net50...
# Epoch 1/100
# 200/200 [==============================] - 24s 73ms/step - loss: 0.9953 - accuracy: 0.8336 - precision: 0.8323 - recall: 0.8356 - val_loss: 4.9848 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.3777 - accuracy: 0.8647 - precision: 0.8588 - recall: 0.8727 - val_loss: 7.7612 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 3/100
# 200/200 [==============================] - 14s 66ms/step - loss: 0.2811 - accuracy: 0.9059 - precision: 0.9070 - recall: 0.9045 - val_loss: 3.3484 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.2389 - accuracy: 0.9164 - precision: 0.9172 - recall: 0.9153 - val_loss: 0.7530 - val_accuracy: 0.5939 - val_precision: 0.5519 - val_recall: 0.9999
# Epoch 5/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.2422 - accuracy: 0.9217 - precision: 0.9205 - recall: 0.9231 - val_loss: 0.5855 - val_accuracy: 0.9230 - val_precision: 0.9098 - val_recall: 0.9392
# Epoch 6/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.3558 - accuracy: 0.8648 - precision: 0.8652 - recall: 0.8641 - val_loss: 162.2071 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.2123 - accuracy: 0.9285 - precision: 0.9284 - recall: 0.9285 - val_loss: 36.6165 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.1909 - accuracy: 0.9335 - precision: 0.9343 - recall: 0.9327 - val_loss: 4.2599 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/100
# 200/200 [==============================] - 14s 67ms/step - loss: 0.1832 - accuracy: 0.9361 - precision: 0.9372 - recall: 0.9348 - val_loss: 0.3230 - val_accuracy: 0.8784 - val_precision: 0.9819 - val_recall: 0.7709
# Epoch 10/100
# 200/200 [==============================] - 14s 66ms/step - loss: 0.1758 - accuracy: 0.9387 - precision: 0.9396 - recall: 0.9376 - val_loss: 0.1957 - val_accuracy: 0.9296 - val_precision: 0.9202 - val_recall: 0.9408
# Epoch 11/100
# 200/200 [==============================] - 15s 71ms/step - loss: 0.1674 - accuracy: 0.9419 - precision: 0.9427 - recall: 0.9409 - val_loss: 0.1859 - val_accuracy: 0.9336 - val_precision: 0.9254 - val_recall: 0.9432
# Epoch 12/100
# 200/200 [==============================] - 14s 67ms/step - loss: 0.1626 - accuracy: 0.9437 - precision: 0.9445 - recall: 0.9428 - val_loss: 0.8734 - val_accuracy: 0.7149 - val_precision: 0.6372 - val_recall: 0.9983
# Epoch 13/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.1580 - accuracy: 0.9450 - precision: 0.9453 - recall: 0.9448 - val_loss: 0.2056 - val_accuracy: 0.9237 - val_precision: 0.8898 - val_recall: 0.9672
# Epoch 14/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.2357 - accuracy: 0.9193 - precision: 0.9097 - recall: 0.9310 - val_loss: 97.3575 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.1477 - accuracy: 0.9512 - precision: 0.9513 - recall: 0.9510 - val_loss: 0.4357 - val_accuracy: 0.8540 - val_precision: 0.7773 - val_recall: 0.9922
# Epoch 16/100
# 200/200 [==============================] - 14s 67ms/step - loss: 0.1351 - accuracy: 0.9540 - precision: 0.9539 - recall: 0.9541 - val_loss: 23.4479 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 17/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.1273 - accuracy: 0.9573 - precision: 0.9575 - recall: 0.9570 - val_loss: 1.1768 - val_accuracy: 0.6184 - val_precision: 0.5671 - val_recall: 1.0000
# Epoch 18/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.1237 - accuracy: 0.9577 - precision: 0.9581 - recall: 0.9573 - val_loss: 0.5855 - val_accuracy: 0.8112 - val_precision: 0.7270 - val_recall: 0.9968
# Epoch 19/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.1185 - accuracy: 0.9600 - precision: 0.9605 - recall: 0.9594 - val_loss: 0.2056 - val_accuracy: 0.9259 - val_precision: 0.9601 - val_recall: 0.8887
# Epoch 20/100
# 200/200 [==============================] - 13s 66ms/step - loss: 0.1123 - accuracy: 0.9622 - precision: 0.9625 - recall: 0.9618 - val_loss: 0.7113 - val_accuracy: 0.7792 - val_precision: 0.9947 - val_recall: 0.5614
# Epoch 21/100
# 200/200 [==============================] - 13s 65ms/step - loss: 0.1123 - accuracy: 0.9618 - precision: 0.9629 - recall: 0.9606 - val_loss: 0.7227 - val_accuracy: 0.7582 - val_precision: 0.9958 - val_recall: 0.5187
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = Net_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 [==============================] - 2s 35ms/step - loss: 0.1859 - accuracy: 0.9336 - precision: 0.9254 - recall: 0.9432
# Val Loss: 0.1859
# Val Accuracy: 0.9336
# Val Precision: 0.9254
# Val Recall: 0.9432

# %%
# Plot error rates and metric rates
plot_metrics(ResNet_model_history, 'loss')
plot_metrics(ResNet_model_history, 'accuracy')
plot_metrics(ResNet_model_history, 'precision')
plot_metrics(ResNet_model_history, 'recall')
