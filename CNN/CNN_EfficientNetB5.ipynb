# %%
# !pip install opendatasets --upgrade --quiet

import pandas as pd
import os
import opendatasets as od

# Assign the Kaggle data set URL into variable
dataset = 'https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images'
# Using opendatasets let's download the data sets
# od.download(dataset)
# # {"username":"kganeshv","key":"224eab20b74a0a68fc7194190f513131"}
# Out:
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
dataset_dir = "cifake-real-and-ai-generated-synthetic-images" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: cifake-real-and-ai-generated-synthetic-images

# %%
# Check if GPUs are available for training
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
img_height = 32
img_width = 32
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
Net_base_model = tf.keras.applications.EfficientNetB5(
    include_top = False,
    weights = 'imagenet',
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
Net_base_model.trainable = True


inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = Net_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256,
          kernel_regularizer = regularizers.l2(0.01),
          activity_regularizer = regularizers.l1(0.01),
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
Net_model = tf.keras.Model(inputs, outputs)

# Compile the model
Net_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Summary of the model
Net_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  efficientnetb5 (Functional)  (None, 2048)             28513527
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 29,062,776
# Trainable params: 28,885,937
# Non-trainable params: 176,839
# _________________________________________________________________

# %%
# Train the Transfer Learning model
print("Starting training with Transfer Learning using Net50...")
ResNet_model_history = Net_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using Net50...
# Epoch 1/100
# 200/200 [==============================] - 86s 257ms/step - loss: 1.4882 - accuracy: 0.9300 - precision: 0.9330 - recall: 0.9266 - val_loss: 1.1444 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 2/100
# 200/200 [==============================] - 47s 234ms/step - loss: 0.2826 - accuracy: 0.9704 - precision: 0.9719 - recall: 0.9688 - val_loss: 0.5068 - val_accuracy: 0.7912 - val_precision: 0.7055 - val_recall: 0.9997
# Epoch 3/100
# 200/200 [==============================] - 47s 233ms/step - loss: 0.1428 - accuracy: 0.9804 - precision: 0.9812 - recall: 0.9794 - val_loss: 0.3306 - val_accuracy: 0.9715 - val_precision: 0.9801 - val_recall: 0.9626
# Epoch 4/100
# 200/200 [==============================] - 47s 231ms/step - loss: 0.0952 - accuracy: 0.9867 - precision: 0.9869 - recall: 0.9865 - val_loss: 0.5960 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 5/100
# 200/200 [==============================] - 47s 233ms/step - loss: 0.0708 - accuracy: 0.9907 - precision: 0.9909 - recall: 0.9906 - val_loss: 0.4606 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 6/100
# 200/200 [==============================] - 46s 231ms/step - loss: 0.0543 - accuracy: 0.9944 - precision: 0.9943 - recall: 0.9944 - val_loss: 0.9550 - val_accuracy: 0.7216 - val_precision: 0.6424 - val_recall: 0.9998
# Epoch 7/100
# 200/200 [==============================] - 47s 233ms/step - loss: 0.0441 - accuracy: 0.9958 - precision: 0.9960 - recall: 0.9957 - val_loss: 0.8484 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 8/100
# 200/200 [==============================] - 47s 232ms/step - loss: 0.0355 - accuracy: 0.9973 - precision: 0.9973 - recall: 0.9972 - val_loss: 0.2078 - val_accuracy: 0.9644 - val_precision: 0.9414 - val_recall: 0.9905
# Epoch 9/100
# 200/200 [==============================] - 47s 234ms/step - loss: 0.0327 - accuracy: 0.9970 - precision: 0.9969 - recall: 0.9971 - val_loss: 0.0913 - val_accuracy: 0.9754 - val_precision: 0.9741 - val_recall: 0.9769
# Epoch 10/100
# 200/200 [==============================] - 47s 235ms/step - loss: 0.0264 - accuracy: 0.9984 - precision: 0.9984 - recall: 0.9983 - val_loss: 0.2281 - val_accuracy: 0.9610 - val_precision: 0.9341 - val_recall: 0.9919
# Epoch 11/100
# 200/200 [==============================] - 47s 233ms/step - loss: 0.0234 - accuracy: 0.9988 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.1613 - val_accuracy: 0.9751 - val_precision: 0.9707 - val_recall: 0.9799
# Epoch 12/100
# 200/200 [==============================] - 47s 233ms/step - loss: 0.0216 - accuracy: 0.9989 - precision: 0.9988 - recall: 0.9990 - val_loss: 0.1626 - val_accuracy: 0.9742 - val_precision: 0.9647 - val_recall: 0.9843
# Epoch 13/100
# 200/200 [==============================] - 47s 233ms/step - loss: 0.0207 - accuracy: 0.9985 - precision: 0.9983 - recall: 0.9986 - val_loss: 0.5825 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 14/100
# 200/200 [==============================] - 47s 232ms/step - loss: 0.0179 - accuracy: 0.9991 - precision: 0.9991 - recall: 0.9992 - val_loss: 0.7331 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 15/100
# 200/200 [==============================] - 47s 232ms/step - loss: 0.0161 - accuracy: 0.9993 - precision: 0.9993 - recall: 0.9993 - val_loss: 0.1728 - val_accuracy: 0.9758 - val_precision: 0.9757 - val_recall: 0.9758
# Epoch 16/100
# 200/200 [==============================] - 47s 232ms/step - loss: 0.0158 - accuracy: 0.9989 - precision: 0.9987 - recall: 0.9990 - val_loss: 0.2267 - val_accuracy: 0.9097 - val_precision: 0.8484 - val_recall: 0.9978
# Epoch 17/100
# 200/200 [==============================] - 47s 232ms/step - loss: 0.0142 - accuracy: 0.9991 - precision: 0.9990 - recall: 0.9992 - val_loss: 0.4357 - val_accuracy: 0.9365 - val_precision: 0.8897 - val_recall: 0.9965
# Epoch 18/100
# 200/200 [==============================] - 46s 231ms/step - loss: 0.0135 - accuracy: 0.9991 - precision: 0.9990 - recall: 0.9993 - val_loss: 4.5093 - val_accuracy: 0.5767 - val_precision: 0.5416 - val_recall: 1.0000
# Epoch 19/100
# 200/200 [==============================] - 47s 234ms/step - loss: 0.0126 - accuracy: 0.9993 - precision: 0.9992 - recall: 0.9994 - val_loss: 0.1279 - val_accuracy: 0.9703 - val_precision: 0.9520 - val_recall: 0.9906
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = Net_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 [==============================] - 4s 106ms/step - loss: 0.0913 - accuracy: 0.9754 - precision: 0.9741 - recall: 0.9769
# Val Loss: 0.0913
# Val Accuracy: 0.9754
# Val Precision: 0.9741
# Val Recall: 0.9769

# %%
# Plot error rates and metric rates
plot_metrics(ResNet_model_history, 'loss')
plot_metrics(ResNet_model_history, 'accuracy')
plot_metrics(ResNet_model_history, 'precision')
plot_metrics(ResNet_model_history, 'recall')
