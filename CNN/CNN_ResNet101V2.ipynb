# %%
# !pip install opendatasets --upgrade --quiet

import pandas as pd
import os
import opendatasets as od

# Assign the Kaggle data set URL into variable
dataset = 'https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images'
# Using opendatasets let's download the data sets
# od.download(dataset)
# # {"username":"kganeshv","key":"224eab20b74a0a68fc7194190f513131"}
# Out:
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
dataset_dir = "cifake-real-and-ai-generated-synthetic-images" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: cifake-real-and-ai-generated-synthetic-images

# %%
# Check if GPUs are available for training
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
img_height = 32
img_width = 32
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
Net_base_model = tf.keras.applications.ResNet101V2(
    include_top = False,
    weights = 'imagenet',
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
Net_base_model.trainable = True


inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = Net_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256,
          kernel_regularizer = regularizers.l2(0.01),
          activity_regularizer = regularizers.l1(0.01),
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
Net_model = tf.keras.Model(inputs, outputs)

# Compile the model
Net_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Summary of the model
Net_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  resnet101v2 (Functional)    (None, 2048)              42626560
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 43,175,809
# Trainable params: 43,074,049
# Non-trainable params: 101,760
# _________________________________________________________________

# %%
# Train the Transfer Learning model
print("Starting training with Transfer Learning using Net50...")
ResNet_model_history = Net_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using Net50...
# Epoch 1/100
# 200/200 [==============================] - 45s 142ms/step - loss: 1.5530 - accuracy: 0.8557 - precision: 0.8724 - recall: 0.8332 - val_loss: 0.7573 - val_accuracy: 0.8742 - val_precision: 0.9705 - val_recall: 0.7719
# Epoch 2/100
# 200/200 [==============================] - 26s 127ms/step - loss: 0.4682 - accuracy: 0.9245 - precision: 0.9220 - recall: 0.9274 - val_loss: 0.5519 - val_accuracy: 0.8249 - val_precision: 0.7428 - val_recall: 0.9941
# Epoch 3/100
# 200/200 [==============================] - 26s 128ms/step - loss: 0.2692 - accuracy: 0.9379 - precision: 0.9324 - recall: 0.9442 - val_loss: 0.2502 - val_accuracy: 0.9340 - val_precision: 0.9653 - val_recall: 0.9004
# Epoch 4/100
# 200/200 [==============================] - 26s 128ms/step - loss: 0.2006 - accuracy: 0.9462 - precision: 0.9423 - recall: 0.9505 - val_loss: 0.2087 - val_accuracy: 0.9344 - val_precision: 0.9323 - val_recall: 0.9367
# Epoch 5/100
# 200/200 [==============================] - 26s 127ms/step - loss: 0.1728 - accuracy: 0.9512 - precision: 0.9454 - recall: 0.9577 - val_loss: 0.3805 - val_accuracy: 0.8798 - val_precision: 0.9893 - val_recall: 0.7678
# Epoch 6/100
# 200/200 [==============================] - 26s 127ms/step - loss: 0.1454 - accuracy: 0.9591 - precision: 0.9536 - recall: 0.9653 - val_loss: 34877144.0000 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/100
# 200/200 [==============================] - 26s 129ms/step - loss: 0.1289 - accuracy: 0.9648 - precision: 0.9606 - recall: 0.9694 - val_loss: 0.1782 - val_accuracy: 0.9433 - val_precision: 0.9286 - val_recall: 0.9603
# Epoch 8/100
# 200/200 [==============================] - 26s 127ms/step - loss: 0.1088 - accuracy: 0.9710 - precision: 0.9667 - recall: 0.9757 - val_loss: 0.3440 - val_accuracy: 0.8837 - val_precision: 0.9910 - val_recall: 0.7744
# Epoch 9/100
# 200/200 [==============================] - 26s 126ms/step - loss: 0.0965 - accuracy: 0.9754 - precision: 0.9725 - recall: 0.9785 - val_loss: 0.2173 - val_accuracy: 0.9460 - val_precision: 0.9624 - val_recall: 0.9284
# Epoch 10/100
# 200/200 [==============================] - 26s 126ms/step - loss: 0.0830 - accuracy: 0.9801 - precision: 0.9779 - recall: 0.9825 - val_loss: 0.2176 - val_accuracy: 0.9334 - val_precision: 0.9772 - val_recall: 0.8875
# Epoch 11/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.0751 - accuracy: 0.9823 - precision: 0.9804 - recall: 0.9843 - val_loss: 0.1714 - val_accuracy: 0.9515 - val_precision: 0.9564 - val_recall: 0.9461
# Epoch 12/100
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0622 - accuracy: 0.9865 - precision: 0.9851 - recall: 0.9879 - val_loss: 0.3022 - val_accuracy: 0.9204 - val_precision: 0.8702 - val_recall: 0.9883
# Epoch 13/100
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0589 - accuracy: 0.9872 - precision: 0.9856 - recall: 0.9888 - val_loss: 0.1740 - val_accuracy: 0.9507 - val_precision: 0.9517 - val_recall: 0.9496
# Epoch 14/100
# 200/200 [==============================] - 25s 125ms/step - loss: 0.0513 - accuracy: 0.9895 - precision: 0.9884 - recall: 0.9906 - val_loss: 0.2137 - val_accuracy: 0.9459 - val_precision: 0.9239 - val_recall: 0.9717
# Epoch 15/100
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0469 - accuracy: 0.9907 - precision: 0.9894 - recall: 0.9919 - val_loss: 0.2195 - val_accuracy: 0.9485 - val_precision: 0.9308 - val_recall: 0.9692
# Epoch 16/100
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0440 - accuracy: 0.9914 - precision: 0.9910 - recall: 0.9918 - val_loss: 0.2369 - val_accuracy: 0.9464 - val_precision: 0.9224 - val_recall: 0.9748
# Epoch 17/100
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0388 - accuracy: 0.9930 - precision: 0.9924 - recall: 0.9936 - val_loss: 0.3026 - val_accuracy: 0.9344 - val_precision: 0.9794 - val_recall: 0.8875
# Epoch 18/100
# 200/200 [==============================] - 26s 127ms/step - loss: 0.0377 - accuracy: 0.9930 - precision: 0.9929 - recall: 0.9932 - val_loss: 0.2263 - val_accuracy: 0.9478 - val_precision: 0.9346 - val_recall: 0.9630
# Epoch 19/100
# 200/200 [==============================] - 26s 128ms/step - loss: 0.0386 - accuracy: 0.9925 - precision: 0.9919 - recall: 0.9931 - val_loss: 0.2688 - val_accuracy: 0.9409 - val_precision: 0.9756 - val_recall: 0.9043
# Epoch 20/100
# 200/200 [==============================] - 25s 126ms/step - loss: 0.0333 - accuracy: 0.9938 - precision: 0.9934 - recall: 0.9942 - val_loss: 0.3178 - val_accuracy: 0.9250 - val_precision: 0.9820 - val_recall: 0.8658
# Epoch 21/100
# 200/200 [==============================] - 26s 128ms/step - loss: 0.0336 - accuracy: 0.9940 - precision: 0.9933 - recall: 0.9947 - val_loss: 0.2090 - val_accuracy: 0.9523 - val_precision: 0.9437 - val_recall: 0.9619
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = Net_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 [==============================] - 2s 40ms/step - loss: 0.1714 - accuracy: 0.9515 - precision: 0.9564 - recall: 0.9461
# Val Loss: 0.1714
# Val Accuracy: 0.9515
# Val Precision: 0.9564
# Val Recall: 0.9461

# %%
# Plot error rates and metric rates
plot_metrics(ResNet_model_history, 'loss')
plot_metrics(ResNet_model_history, 'accuracy')
plot_metrics(ResNet_model_history, 'recall')
plot_metrics(ResNet_model_history, 'precision')
