# %%
# !pip install opendatasets --upgrade --quiet

import pandas as pd
import os
import opendatasets as od

# Assign the Kaggle data set URL into variable
dataset = 'https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images'
# Using opendatasets let's download the data sets
# od.download(dataset)
# # {"username":"kganeshv","key":"224eab20b74a0a68fc7194190f513131"}
# Out:
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %% [markdown]
# ## Fine-tuning CNN for AI-generated Image Detection
# In this notebook, we will explore the task of classifying images as real or AI-generated using fine-tuning techniques with several well-known CNN architectures. For this classification task, we will use the CIFAKE dataset, which includes both real and AI-generated images.
#
# Link for the dataset: [CIFAKE: Real and AI-Generated Synthetic Images](https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
dataset_dir = "cifake-real-and-ai-generated-synthetic-images" # For Kaggle notebooks. If you run locally, point this line to the CIFAKE directory
print("Loading dataset from: " + dataset_dir)
# Out:
# Loading dataset from: cifake-real-and-ai-generated-synthetic-images

# %%
# Check if GPUs are available for training
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
img_height = 75
img_width = 75
batch_size = 500

# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/train",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

# Load the validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
  dataset_dir + "/test",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = val_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %% [markdown]
# Larger batch sizes are expected to result in significantly longer training times, especially with a substantial training set of 100,000 images. However, the compact size of the images effectively reduces the impact on training duration.

# %%
# Function for plotting the error rate and metrics rate
def plot_metrics(history, metric):
    plt.plot(history.history[metric], label = metric)
    plt.plot(history.history['val_' + metric], label='val_' + metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# Constant values that will be shared by all the models
val_true_classes = np.concatenate([y for x, y in val_ds], axis = 0)  # Get true labels
class_names = ['FAKE', 'REAL']
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True)

# %% [markdown]
# ### Model Building
#
# All the models share the same architecture for a fair comparison: the input layer, followed by the base model with pre-trained weights from the imagenet, then a few dense layers, and then a unit output with a sigmoid activation function.
#
# Training is conducted with early stopping criteria monitoring the validation loss, and the best weights will be restored once the training is completed.

# %%
Net_base_model = tf.keras.applications.InceptionV3(
    include_top = False,
    weights = 'imagenet',
    input_shape = (img_height, img_width, 3),
    pooling = 'max'
)
Net_base_model.trainable = True


inputs = tf.keras.Input(shape = (img_height, img_width, 3))
x = Net_base_model(inputs, training = False)
x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256,
          kernel_regularizer = regularizers.l2(0.01),
          activity_regularizer = regularizers.l1(0.01),
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)
x = Dense(64, activation = 'relu')(x)
outputs = Dense(1, activation = 'sigmoid')(x)
Net_model = tf.keras.Model(inputs, outputs)

# Compile the model
Net_model.compile(
    optimizer = tf.keras.optimizers.Adamax(learning_rate = .001),
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# Summary of the model
Net_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  batch_normalization_94 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 22,352,033
# Trainable params: 22,313,505
# Non-trainable params: 38,528
# _________________________________________________________________

# %%
# Train the Transfer Learning model
print("Starting training with Transfer Learning using Net50...")
ResNet_model_history = Net_model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100,
    verbose = 1,
    callbacks = [early_stopping]
)
print("Transfer Learning training finished.")
# Out:
# Starting training with Transfer Learning using Net50...
# Epoch 1/100
# 200/200 [==============================] - 52s 190ms/step - loss: 3.1415 - accuracy: 0.7661 - precision: 0.7563 - recall: 0.7854 - val_loss: 2.1307 - val_accuracy: 0.7158 - val_precision: 0.9852 - val_recall: 0.4382
# Epoch 2/100
# 200/200 [==============================] - 36s 180ms/step - loss: 1.1109 - accuracy: 0.9153 - precision: 0.9180 - recall: 0.9119 - val_loss: 0.8228 - val_accuracy: 0.8943 - val_precision: 0.9751 - val_recall: 0.8094
# Epoch 3/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.4955 - accuracy: 0.9332 - precision: 0.9410 - recall: 0.9244 - val_loss: 0.3493 - val_accuracy: 0.9367 - val_precision: 0.9578 - val_recall: 0.9137
# Epoch 4/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.2980 - accuracy: 0.9406 - precision: 0.9501 - recall: 0.9302 - val_loss: 0.2557 - val_accuracy: 0.9460 - val_precision: 0.9312 - val_recall: 0.9632
# Epoch 5/100
# 200/200 [==============================] - 37s 181ms/step - loss: 0.2297 - accuracy: 0.9467 - precision: 0.9557 - recall: 0.9367 - val_loss: 0.2135 - val_accuracy: 0.9456 - val_precision: 0.9372 - val_recall: 0.9553
# Epoch 6/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.1983 - accuracy: 0.9510 - precision: 0.9604 - recall: 0.9407 - val_loss: 0.1961 - val_accuracy: 0.9391 - val_precision: 0.9760 - val_recall: 0.9002
# Epoch 7/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.1811 - accuracy: 0.9542 - precision: 0.9632 - recall: 0.9446 - val_loss: 0.2021 - val_accuracy: 0.9520 - val_precision: 0.9397 - val_recall: 0.9659
# Epoch 8/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.1685 - accuracy: 0.9563 - precision: 0.9656 - recall: 0.9462 - val_loss: 0.4343 - val_accuracy: 0.8815 - val_precision: 0.8114 - val_recall: 0.9940
# Epoch 9/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.1574 - accuracy: 0.9596 - precision: 0.9676 - recall: 0.9511 - val_loss: 0.2756 - val_accuracy: 0.9223 - val_precision: 0.8723 - val_recall: 0.9896
# Epoch 10/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.1485 - accuracy: 0.9612 - precision: 0.9678 - recall: 0.9542 - val_loss: 0.2423 - val_accuracy: 0.9077 - val_precision: 0.9910 - val_recall: 0.8229
# Epoch 11/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.1386 - accuracy: 0.9665 - precision: 0.9665 - recall: 0.9664 - val_loss: 0.8140 - val_accuracy: 0.6769 - val_precision: 0.6075 - val_recall: 0.9997
# Epoch 12/100
# 200/200 [==============================] - 37s 181ms/step - loss: 0.1252 - accuracy: 0.9688 - precision: 0.9664 - recall: 0.9714 - val_loss: 0.1433 - val_accuracy: 0.9582 - val_precision: 0.9606 - val_recall: 0.9557
# Epoch 13/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.1178 - accuracy: 0.9715 - precision: 0.9689 - recall: 0.9743 - val_loss: 0.3086 - val_accuracy: 0.9016 - val_precision: 0.8393 - val_recall: 0.9934
# Epoch 14/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.1067 - accuracy: 0.9737 - precision: 0.9696 - recall: 0.9780 - val_loss: 0.2913 - val_accuracy: 0.9165 - val_precision: 0.8611 - val_recall: 0.9934
# Epoch 15/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0971 - accuracy: 0.9764 - precision: 0.9728 - recall: 0.9802 - val_loss: 0.1466 - val_accuracy: 0.9585 - val_precision: 0.9472 - val_recall: 0.9711
# Epoch 16/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0883 - accuracy: 0.9801 - precision: 0.9771 - recall: 0.9833 - val_loss: 0.1711 - val_accuracy: 0.9384 - val_precision: 0.8986 - val_recall: 0.9884
# Epoch 17/100
# 200/200 [==============================] - 36s 177ms/step - loss: 0.0799 - accuracy: 0.9825 - precision: 0.9792 - recall: 0.9858 - val_loss: 0.1741 - val_accuracy: 0.9334 - val_precision: 0.8895 - val_recall: 0.9896
# Epoch 18/100
# 200/200 [==============================] - 36s 179ms/step - loss: 0.0795 - accuracy: 0.9826 - precision: 0.9787 - recall: 0.9866 - val_loss: 0.1385 - val_accuracy: 0.9601 - val_precision: 0.9550 - val_recall: 0.9657
# Epoch 19/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0673 - accuracy: 0.9857 - precision: 0.9833 - recall: 0.9881 - val_loss: 0.2102 - val_accuracy: 0.9406 - val_precision: 0.9022 - val_recall: 0.9885
# Epoch 20/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0648 - accuracy: 0.9864 - precision: 0.9832 - recall: 0.9897 - val_loss: 0.1675 - val_accuracy: 0.9597 - val_precision: 0.9568 - val_recall: 0.9630
# Epoch 21/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0573 - accuracy: 0.9889 - precision: 0.9865 - recall: 0.9915 - val_loss: 0.2059 - val_accuracy: 0.9491 - val_precision: 0.9198 - val_recall: 0.9840
# Epoch 22/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0592 - accuracy: 0.9876 - precision: 0.9846 - recall: 0.9908 - val_loss: 0.2025 - val_accuracy: 0.9500 - val_precision: 0.9202 - val_recall: 0.9854
# Epoch 23/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0488 - accuracy: 0.9915 - precision: 0.9895 - recall: 0.9935 - val_loss: 0.1704 - val_accuracy: 0.9549 - val_precision: 0.9343 - val_recall: 0.9785
# Epoch 24/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0500 - accuracy: 0.9910 - precision: 0.9886 - recall: 0.9934 - val_loss: 0.1267 - val_accuracy: 0.9631 - val_precision: 0.9595 - val_recall: 0.9670
# Epoch 25/100
# 200/200 [==============================] - 35s 175ms/step - loss: 0.0437 - accuracy: 0.9924 - precision: 0.9910 - recall: 0.9938 - val_loss: 0.1572 - val_accuracy: 0.9607 - val_precision: 0.9516 - val_recall: 0.9709
# Epoch 26/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0431 - accuracy: 0.9922 - precision: 0.9904 - recall: 0.9940 - val_loss: 0.1809 - val_accuracy: 0.9632 - val_precision: 0.9535 - val_recall: 0.9740
# Epoch 27/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0381 - accuracy: 0.9937 - precision: 0.9921 - recall: 0.9954 - val_loss: 0.3680 - val_accuracy: 0.9237 - val_precision: 0.9910 - val_recall: 0.8552
# Epoch 28/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.0383 - accuracy: 0.9935 - precision: 0.9921 - recall: 0.9948 - val_loss: 0.5777 - val_accuracy: 0.8958 - val_precision: 0.9935 - val_recall: 0.7968
# Epoch 29/100
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0394 - accuracy: 0.9931 - precision: 0.9917 - recall: 0.9945 - val_loss: 0.1665 - val_accuracy: 0.9603 - val_precision: 0.9567 - val_recall: 0.9644
# Epoch 30/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.0343 - accuracy: 0.9946 - precision: 0.9935 - recall: 0.9958 - val_loss: 0.3064 - val_accuracy: 0.9480 - val_precision: 0.9877 - val_recall: 0.9073
# Epoch 31/100
# 200/200 [==============================] - 34s 169ms/step - loss: 0.0390 - accuracy: 0.9934 - precision: 0.9916 - recall: 0.9953 - val_loss: 0.1981 - val_accuracy: 0.9439 - val_precision: 0.9079 - val_recall: 0.9882
# Epoch 32/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0363 - accuracy: 0.9946 - precision: 0.9931 - recall: 0.9961 - val_loss: 0.1645 - val_accuracy: 0.9614 - val_precision: 0.9458 - val_recall: 0.9790
# Epoch 33/100
# 200/200 [==============================] - 36s 178ms/step - loss: 0.0279 - accuracy: 0.9965 - precision: 0.9953 - recall: 0.9977 - val_loss: 0.2749 - val_accuracy: 0.9572 - val_precision: 0.9856 - val_recall: 0.9280
# Epoch 34/100
# 200/200 [==============================] - 34s 170ms/step - loss: 0.0289 - accuracy: 0.9962 - precision: 0.9952 - recall: 0.9972 - val_loss: 7979.6318 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Transfer Learning training finished.

# %%
# Evaluate the model on the test dataset
val_loss, val_accuracy, val_precision, val_recall = Net_model.evaluate(val_ds)

# Print the metrics
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
# Out:
# 40/40 [==============================] - 3s 63ms/step - loss: 0.1267 - accuracy: 0.9631 - precision: 0.9595 - recall: 0.9670
# Val Loss: 0.1267
# Val Accuracy: 0.9631
# Val Precision: 0.9595
# Val Recall: 0.9670

# %%
# Plot error rates and metric rates
plot_metrics(ResNet_model_history, 'loss')
plot_metrics(ResNet_model_history, 'accuracy')
plot_metrics(ResNet_model_history, 'recall')
plot_metrics(ResNet_model_history, 'precision')
